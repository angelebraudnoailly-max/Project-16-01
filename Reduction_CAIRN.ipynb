# %%
import pandas as pd

# Lire le CSV complet
df = pd.read_csv("CAIRN_LDA_FINAL2.csv")

# Colonnes à garder
cols_to_keep = [
    "url",
    "Unnamed: 0",
    "titre",
    "auteur",
    "section",
    "twitter_card",
    "journal",
    "annee",
    "numero",
    "name",
    "any_author_in_chunk",
    "author_present_in_article_x",
    "author_present_in_article_y",
    "author_present_in_article",
    "langue",
    "tokens",
    "topics_proportions_concat",
    "top_2_topics_with_prop",
    "top_4_topics_with_prop"
]

# Créer le nouveau DataFrame light
df_light = df[cols_to_keep]

# Nettoyer les colonnes booléennes
bool_cols = [
    "any_author_in_chunk",
    "author_present_in_article_x",
    "author_present_in_article_y",
    "author_present_in_article"
]

for col in bool_cols:
    df_light[col] = df_light[col].apply(lambda x: False if pd.isna(x) else True if str(x) in ["1", "1.0", "True", "true"] else False)

# Exporter en CSV light
df_light.to_csv("CAIRN_LDA_LIGHT.csv", index=False, encoding="utf-8")
print("CSV allégé créé : CAIRN_LDA_LIGHT.csv")
# Out:
# /var/folders/tt/y9bw1l4d3qj30pkppbrwz1v40000gn/T/ipykernel_56579/627404661.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_light[col] = df_light[col].apply(lambda x: False if pd.isna(x) else True if str(x) in ["1", "1.0", "True", "true"] else False)
# CSV allégé créé : CAIRN_LDA_LIGHT.csv

# %%
display(df_light)
# Out:
#                                                      url  \
# 0      https://droit.cairn.info/Economie-des-donnees-...
# 1      https://droit.cairn.info/Economie-des-donnees-...
# 2      https://droit.cairn.info/Economie-des-donnees-...
# 3      https://droit.cairn.info/Economie-des-donnees-...
# 4      https://droit.cairn.info/Economie-des-donnees-...
# ...                                                  ...
# 89500  https://stm.cairn.info/violences-de-la-maladie...
# 89501  https://stm.cairn.info/violences-de-la-maladie...
# 89502  https://stm.cairn.info/violences-de-la-maladie...
# 89503  https://stm.cairn.info/violences-de-la-maladie...
# 89504  https://stm.cairn.info/violences-de-la-maladie...
#
#                   Unnamed: 0  \
# 0                      86147
# 1                      86147
# 2                      86147
# 3                      86147
# 4                      86147
# ...                      ...
# 89500  26782 | 20315 | 22977
# 89501  26782 | 20315 | 22977
# 89502  26782 | 20315 | 22977
# 89503  26782 | 20315 | 22977
# 89504  26782 | 20315 | 22977
#
#                                                    titre               auteur  \
# 0      IV. Les comportements en matière de vie privée...  Fabrice Rochelandet
# 1      IV. Les comportements en matière de vie privée...  Fabrice Rochelandet
# 2      IV. Les comportements en matière de vie privée...  Fabrice Rochelandet
# 3      IV. Les comportements en matière de vie privée...  Fabrice Rochelandet
# 4      IV. Les comportements en matière de vie privée...  Fabrice Rochelandet
# ...                                                  ...                  ...
# 89500                      2. Géométrie de la souffrance         Claire Marin
# 89501                      2. Géométrie de la souffrance         Claire Marin
# 89502                      2. Géométrie de la souffrance         Claire Marin
# 89503                      2. Géométrie de la souffrance         Claire Marin
# 89504                      2. Géométrie de la souffrance         Claire Marin
#
#           section twitter_card             journal   annee numero  \
# 0      Sociologie      summary             Repères  2010.0    NaN
# 1      Sociologie      summary             Repères  2010.0    NaN
# 2      Sociologie      summary             Repères  2010.0    NaN
# 3      Sociologie      summary             Repères  2010.0    NaN
# 4      Sociologie      summary             Repères  2010.0    NaN
# ...           ...          ...                 ...     ...    ...
# 89500  Sociologie      summary  Le temps des idées  2015.0    NaN
# 89501  Sociologie      summary  Le temps des idées  2015.0    NaN
# 89502  Sociologie      summary  Le temps des idées  2015.0    NaN
# 89503  Sociologie      summary  Le temps des idées  2015.0    NaN
# 89504  Sociologie      summary  Le temps des idées  2015.0    NaN
#
#                      name  any_author_in_chunk  author_present_in_article_x  \
# 0          Galia Ackerman                False                         True
# 1          Galia Ackerman                False                         True
# 2          Galia Ackerman                 True                         True
# 3          Galia Ackerman                False                         True
# 4          Galia Ackerman                False                         True
# ...                   ...                  ...                          ...
# 89500  Fiodor Dostoïevski                False                         True
# 89501  Fiodor Dostoïevski                 True                         True
# 89502  Fiodor Dostoïevski                False                         True
# 89503  Fiodor Dostoïevski                 True                         True
# 89504  Fiodor Dostoïevski                False                         True
#
#        author_present_in_article_y  author_present_in_article langue  \
# 0                             True                       True     fr
# 1                             True                       True     fr
# 2                             True                       True     fr
# 3                             True                       True     fr
# 4                             True                       True     fr
# ...                            ...                        ...    ...
# 89500                         True                       True     fr
# 89501                         True                       True     fr
# 89502                         True                       True     fr
# 89503                         True                       True     fr
# 89504                         True                       True     fr
#
#                                                   tokens  \
# 0      ['objectif', 'chapitre', 'envisager', 'forme',...
# 1      ['dépendre', 'part', 'identité', 'donner', 'id...
# 2      ['politique', 'inverse', 'envisageable', 'savo...
# 3      ['supposer', 'maximiser', 'utilité', 'manière'...
# 4      ['décalage', 'entrer', 'action', 'présenter', ...
# ...                                                  ...
# 89500  ['disparaître', 'existence', 'possibilité', 'd...
# 89501  ['décrire', 'littérature', 'médical', 'passer'...
# 89502  ['perception', 'faire', 'dérouter', 'sujet', '...
# 89503  ['sujet', 'ramener', 'luire', 'biais', 'artifi...
# 89504  ['logique', 'maladie', 'dégradation', 'progres...
#
#                                topics_proportions_concat  \
# 0      topic_0 (siècle):0.000 | topic_1 (jeune):0.011...
# 1      topic_0 (siècle):0.000 | topic_1 (jeune):0.000...
# 2      topic_0 (siècle):0.000 | topic_1 (jeune):0.000...
# 3      topic_0 (siècle):0.000 | topic_1 (jeune):0.007...
# 4      topic_0 (siècle):0.000 | topic_1 (jeune):0.000...
# ...                                                  ...
# 89500  topic_0 (siècle):0.000 | topic_1 (jeune):0.000...
# 89501  topic_0 (siècle):0.000 | topic_1 (jeune):0.000...
# 89502  topic_0 (siècle):0.000 | topic_1 (jeune):0.000...
# 89503  topic_0 (siècle):0.000 | topic_1 (jeune):0.013...
# 89504  topic_0 (siècle):0.000 | topic_1 (jeune):0.000...
#
#                                   top_2_topics_with_prop  \
# 0      [('topic_42 (social)', 0.328), ('topic_29 (ind...
# 1      [('topic_42 (social)', 0.232), ('topic_29 (ind...
# 2      [('topic_44 (modèle)', 0.153), ('topic_29 (ind...
# 3      [('topic_44 (modèle)', 0.327), ('topic_8 (info...
# 4      [('topic_48 (entreprise)', 0.217), ('topic_44 ...
# ...                                                  ...
# 89500  [('topic_49 (mort)', 0.25), ('topic_15 (sens)'...
# 89501  [('topic_49 (mort)', 0.29), ('topic_15 (sens)'...
# 89502  [('topic_49 (mort)', 0.288), ('topic_15 (sens)...
# 89503  [('topic_15 (sens)', 0.301), ('topic_49 (mort)...
# 89504  [('topic_15 (sens)', 0.374), ('topic_22 (philo...
#
#                                   top_4_topics_with_prop
# 0      [(42, 0.328), (29, 0.201), (48, 0.192), (55, 0...
# 1      [(42, 0.232), (29, 0.128), (48, 0.122), (44, 0...
# 2      [(44, 0.153), (29, 0.153), (8, 0.125), (42, 0....
# 3      [(44, 0.327), (8, 0.157), (48, 0.149), (29, 0....
# 4      [(48, 0.217), (44, 0.193), (29, 0.173), (9, 0....
# ...                                                  ...
# 89500  [(49, 0.25), (15, 0.198), (29, 0.163), (22, 0....
# 89501  [(49, 0.29), (15, 0.178), (29, 0.118), (22, 0....
# 89502  [(49, 0.288), (15, 0.256), (22, 0.121), (29, 0...
# 89503  [(15, 0.301), (49, 0.247), (22, 0.13), (29, 0....
# 89504  [(15, 0.374), (22, 0.252), (29, 0.124), (49, 0...
#
# [89505 rows x 19 columns]
